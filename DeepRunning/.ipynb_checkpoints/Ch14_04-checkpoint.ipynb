# %% [markdown]
# 중도 정지

# %%
from tensorflow.keras import models, layers
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data/wine.csv',header=None)
X=df.iloc[:,:12]
y=df.iloc[:,12]
X_train,X_test,y_train,y_test=\
train_test_split(X,y,test_size=0.2,shuffle=True)

# %%
model =models.Sequential()
model.add(layers.Dense(30,input_dim=12,activation='relu'))
model.add(layers.Dense(12,activation='relu'))
model.add(layers.Dense(8,activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
eatly_stooping=EarlyStopping(monitor='val_loss',patience=20)#val_loss가 20번 이상 좋아지지않으면 정지
model_path='./model/best_model.hdf5'
checkpoint=ModelCheckpoint(filepath=model_path,monitor='val_loss',verbose=0,
                          save_best_only=True)#val_loss가 더 좋아지면 저장=최고값 저장

# %%
history=model.fit(X_train,y_train,epochs=2000,batch_size=500,
          validation_split=0.25,callbacks=[eatly_stooping,checkpoint])
# Out:
# Epoch 1/2000
# C:\Users\BIT\miniconda3\envs\ml-env\lib\site-packages\keras\engine\data_adapter.py:1699: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 8/8 [==============================] - 1s 42ms/step - loss: 5.9327 - accuracy: 0.2397 - val_loss: 3.9111 - val_accuracy: 0.2215
# Epoch 2/2000
# 8/8 [==============================] - 0s 14ms/step - loss: 2.6421 - accuracy: 0.1763 - val_loss: 1.1283 - val_accuracy: 0.3385
# Epoch 3/2000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7409 - accuracy: 0.5810 - val_loss: 0.5660 - val_accuracy: 0.7385
# Epoch 4/2000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5689 - accuracy: 0.7542 - val_loss: 0.6022 - val_accuracy: 0.7500
# ...

# %%
score=model.evaluate(X_test,y_test)
print('Test Accuracy:',score[1])
# Out:
# 41/41 [==============================] - 0s 1ms/step - loss: 0.0651 - accuracy: 0.9831
# Test Accuracy: 0.9830769300460815
